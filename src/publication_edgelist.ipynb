# %%
import re
import requests
import pandas as pd
import concurrent.futures
from time import time

# Global session to reuse HTTP connections.
session = requests.Session()


def extract_doi(doi_str: str) -> str:
    """
    Extract the DOI from a given string.

    Handles:
      - URLs (e.g. "https://doi.org/10.xxx/yyy")
      - Text with "doi:" prefix.

    Parameters:
        doi_str (str): The input DOI string.

    Returns:
        str: The cleaned DOI (e.g., "10.xxx/yyy").
    """
    doi_str = doi_str.strip()
    if doi_str.lower().startswith("https://doi.org/"):
        return doi_str.split("https://doi.org/")[-1]
    match = re.search(r"doi:(\S+)", doi_str, re.IGNORECASE)
    if match:
        return match.group(1)
    return doi_str


def get_references(doi: str) -> list:
    """
    Retrieve outgoing reference edges for the given DOI via the OpenCitations API.

    For each edge, the publication is the origin (which cites others)
    and the returned "cited" DOI is the target.

    Parameters:
        doi (str): The DOI to query.

    Returns:
        list: List of dictionaries; each dictionary contains:
              "origin_doi" and "target_doi".
    """
    url = f"https://opencitations.net/index/api/v2/references/doi:{doi}"
    try:
        response = session.get(url, timeout=10)
    except Exception as e:
        print(f"Request error (references) for {doi}: {e}")
        return []

    edges = []
    if response.status_code == 200:
        try:
            data = response.json()
        except Exception as e:
            print(f"JSON parse error for references of {doi}: {e}")
            return []
        for record in data:
            cited_raw = record.get("cited")
            if cited_raw:
                cleaned_doi = extract_doi(cited_raw)
                edges.append({"origin_doi": doi, "target_doi": cleaned_doi})
    else:
        print(f"Error {response.status_code} when fetching references for {doi}")
    return edges


def get_citations(doi: str) -> list:
    """
    Retrieve incoming citation edges for the given DOI via the OpenCitations API.

    For each edge, the returned "citing" DOI is the origin,
    and the given DOI is the target.

    Parameters:
        doi (str): The DOI to query.

    Returns:
        list: List of dictionaries with keys "origin_doi" and "target_doi".
    """
    url = f"https://opencitations.net/index/api/v2/citations/doi:{doi}"
    try:
        response = session.get(url, timeout=10)
    except Exception as e:
        print(f"Request error (citations) for {doi}: {e}")
        return []

    edges = []
    if response.status_code == 200:
        try:
            data = response.json()
        except Exception as e:
            print(f"JSON parse error for citations of {doi}: {e}")
            return []
        for record in data:
            citing_raw = record.get("citing")
            if citing_raw:
                cleaned_doi = extract_doi(citing_raw)
                edges.append({"origin_doi": cleaned_doi, "target_doi": doi})
    else:
        print(f"Error {response.status_code} when fetching citations for {doi}")
    return edges


def process_doi(doi: str, sub_area: str) -> list:
    """
    Process a single publication (identified by DOI and its sub-area) by:
      - Retrieving its references (outgoing edges) and setting:
          * origin_sub_area = sub_area
          * target_sub_area = None (to be filled later if available)
      - Retrieving its citations (incoming edges) and setting:
          * origin_sub_area = None
          * target_sub_area = sub_area

    Parameters:
        doi (str): The publication's DOI.
        sub_area (str): The publication's known sub-area.

    Returns:
        list: A combined list of edge dictionaries.
    """
    # Outgoing: publication is origin.
    refs = get_references(doi)
    for edge in refs:
        edge["origin_sub_area"] = sub_area
        edge["target_sub_area"] = None

    # Incoming: publication is target.
    cits = get_citations(doi)
    for edge in cits:
        edge["origin_sub_area"] = None
        edge["target_sub_area"] = sub_area

    return refs + cits


def load_publications_for_area(file_url: str, sub_area: str) -> list:
    """
    Load publication data from a CSV file at the given URL and tag each publication
    with the provided sub-area. Assumes the CSV file (without headers) has the DOI
    in column index 5.

    Parameters:
        file_url (str): URL to the CSV file.
        sub_area (str): The sub-area for these publications.

    Returns:
        list: List of tuples (doi, sub_area).
    """
    try:
        df = pd.read_csv(file_url, header=None)
    except Exception as e:
        print(f"Error loading CSV from {file_url}: {e}")
        return []
    doi_series = df.iloc[:, 5].dropna().astype(str)
    publications = []
    for doi in doi_series:
        if doi.strip().lower() != "null":
            cleaned = extract_doi(doi)
            publications.append((cleaned, sub_area))
    return list(set(publications))


def main():
    base_url = (
        "https://raw.githubusercontent.com/aserg-ufmg/CSIndex/refs/heads/master/data/"
    )
    areas = [
        "ai",
        "arch",
        "bio",
        "chi",
        "cse",
        "data",
        "dbis",
        "ds",
        "formal",
        "graphics",
        "hardware",
        "ir",
        "net",
        "or",
        "pl",
        "robotics",
        "se",
        "security",
        "theory",
        "vision",
    ]

    all_publications = []
    print("Loading publication data for each area...")
    for area in areas:
        file_url = f"{base_url}{area}-out-papers.csv"
        pubs = load_publications_for_area(file_url, area)
        print(f"Area {area}: found {len(pubs)} publications.")
        all_publications.extend(pubs)

    # Build a dictionary mapping each publication DOI to its sub-area.
    repo_dict = {doi: sub_area for doi, sub_area in all_publications}
    print(f"Total unique repository publications: {len(repo_dict)}")

    all_edges = []
    start_time = time()

    # Process each publication concurrently.
    with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
        future_to_pub = {
            executor.submit(process_doi, doi, sub_area): (doi, sub_area)
            for doi, sub_area in all_publications
        }
        for future in concurrent.futures.as_completed(future_to_pub):
            doi, sub_area = future_to_pub[future]
            try:
                edges = future.result()
                all_edges.extend(edges)
            except Exception as e:
                print(f"Error processing {doi} ({sub_area}): {e}")

    elapsed = time() - start_time
    print(f"Processed {len(all_publications)} publications in {elapsed:.2f} seconds.")

    # Filter edges: keep only those where both origin and target are in our repository.
    filtered_edges = []
    for edge in all_edges:
        origin_doi = edge.get("origin_doi")
        target_doi = edge.get("target_doi")
        if origin_doi in repo_dict and target_doi in repo_dict:
            # If sub-area information is missing, fill it from our repository dictionary.
            if edge.get("origin_sub_area") is None:
                edge["origin_sub_area"] = repo_dict[origin_doi]
            if edge.get("target_sub_area") is None:
                edge["target_sub_area"] = repo_dict[target_doi]
            filtered_edges.append(edge)

    print(f"Total citation edges after filtering: {len(filtered_edges)}")

    # Create final DataFrame with desired column order.
    df_edges = pd.DataFrame(filtered_edges)
    for col in ["origin_doi", "origin_sub_area", "target_doi", "target_sub_area"]:
        if col not in df_edges.columns:
            df_edges[col] = None
    df_edges = df_edges[
        ["origin_doi", "origin_sub_area", "target_doi", "target_sub_area"]
    ]
    df_edges.drop_duplicates(inplace=True)

    print(f"Unique citation edges in the repository-only network: {len(df_edges)}")
    df_edges.to_csv("citations_edge_list_repo_only.csv", index=False)
    print("Filtered citation edge list saved to 'citations_edge_list_repo_only.csv'.")


if __name__ == "__main__":
    main()
# Out:
# Loading publication data for each area...
# Area ai: found 602 publications.
# Area arch: found 227 publications.
# Area bio: found 59 publications.
# Area chi: found 86 publications.
# Area cse: found 25 publications.
# Area data: found 145 publications.
# Area dbis: found 106 publications.
# Area ds: found 109 publications.
# Area formal: found 33 publications.
# Area graphics: found 219 publications.
# Area hardware: found 69 publications.
# Area ir: found 55 publications.
# Area net: found 339 publications.
# Area or: found 270 publications.
# Area pl: found 20 publications.
# Area robotics: found 121 publications.
# Area se: found 441 publications.
# Area security: found 50 publications.
# Area theory: found 170 publications.
# Area vision: found 143 publications.
# Total unique repository publications: 3289
# Error 500 when fetching citations for 10.24963/ijcai.2020/679
# Error 500 when fetching references for 10.1016/j.eswa.2021.115589
# Error 500 when fetching citations for 10.1016/j.eswa.2021.115064
# Error 500 when fetching citations for 10.1109/TFUZZ.2022.3176916
# Error 500 when fetching references for 10.1016/j.eswa.2021.115222
# Error 500 when fetching references for 10.1145/3512290.3528743
# Error 500 when fetching citations for 10.1016/j.eswa.2023.120536
# Error 500 when fetching references for 10.1016/j.eswa.2023.123086
# Error 500 when fetching citations for 10.1016/j.ijar.2024.109171
# Error 500 when fetching references for 10.1609/aaai.v34i06.6548
# Error 500 when fetching citations for 10.1145/3576050.3576112
# Error 500 when fetching references for 10.1016/j.eswa.2022.117204
# Error 500 when fetching references for 10.1007/s11227-022-05024-y
# Error 500 when fetching references for 10.1016/j.jpdc.2023.01.006
# Error 500 when fetching references for 10.1109/TCBB.2020.3028776
# Error 500 when fetching references for 10.1109/BIBM49941.2020.9313575
# Error 500 when fetching references for 10.1109/BIBM49941.2020.9313226
# Error 500 when fetching citations for 10.1109/TCBB.2022.3215615
# Error 500 when fetching references for 10.1016/j.ijhcs.2023.103046
# Error 500 when fetching citations for 10.1145/3627043.3659558
# Error 500 when fetching citations for 10.1145/3469128
# Error 500 when fetching citations for 10.1016/j.inffus.2022.09.006
# Error 500 when fetching references for 10.1016/j.ins.2021.07.076
# Error 500 when fetching citations for 10.1016/j.ins.2020.07.050
# Error 500 when fetching citations for 10.1016/j.inffus.2022.09.001
# Error 500 when fetching citations for 10.1109/BigData50022.2020.9377877
# Error 500 when fetching citations for 10.1016/j.ins.2024.120300
# Error 500 when fetching citations for 10.1016/j.ins.2020.03.004
# Error 500 when fetching references for https://proceedings.neurips.cc/paper/2021/hash/5934c1ec0cd31e12bd9084d106bc2e32-Abstract.html
# Error 500 when fetching references for 10.1137/1.9781611977653.ch84
# Error 500 when fetching citations for https://jmlr.org/papers/v21/19-348.html
# Error 500 when fetching citations for http://papers.nips.cc/paper_files/paper/2023/hash/770b3ecb70147a2d2f18d2964fafcdd5-Abstract-Conference.html
# Error 500 when fetching citations for 10.1007/978-3-030-67658-2_12
# Error 500 when fetching citations for 10.1109/BigData52589.2021.9671985
# Error 500 when fetching citations for 10.1016/j.is.2020.101553
# Error 500 when fetching citations for 10.1016/j.datak.2023.102253
# Error 500 when fetching references for 10.1007/978-3-031-17995-2_2
# Error 500 when fetching references for 10.1007/978-3-031-17995-2_1
# Error 500 when fetching references for 10.1016/j.is.2021.101896
# Error 500 when fetching citations for 10.1016/j.is.2019.101454
# Error 500 when fetching citations for 10.1016/j.is.2021.101941
# Error 500 when fetching references for 10.1109/ISSRE62328.2024.00020
# Error 500 when fetching references for 10.1007/s10723-021-09588-6
# Error 500 when fetching citations for 10.1002/spe.3056
# Error 500 when fetching citations for 10.1109/TCC.2022.3177668
# Error 500 when fetching references for 10.1016/j.jss.2024.112222
# Error 500 when fetching references for 10.1109/CCGrid49817.2020.00-55
# Error 500 when fetching references for 10.1016/j.jss.2023.111826
# Error 500 when fetching citations for 10.1016/j.scico.2021.102764
# Error 500 when fetching references for 10.1017/S0960129521000050
# Error 500 when fetching citations for 10.46298/lmcs-19(1:18)2023
# Error 500 when fetching citations for 10.1145/3441655
# Error 500 when fetching citations for 10.1016/j.scico.2022.102791
# Error 500 when fetching citations for 10.1016/j.scico.2020.102536
# Error 500 when fetching citations for 10.1145/3386569.3392403Error 500 when fetching references for 10.1109/TVCG.2020.3012120
#
# Error 500 when fetching references for 10.1007/s11042-020-10384-9
# Error 500 when fetching citations for 10.1007/s11042-020-09272-z
# Error 500 when fetching citations for 10.1007/s11042-020-10175-2
# Error 500 when fetching references for 10.1109/TVCG.2022.3175626
# Error 500 when fetching citations for 10.1109/TVCG.2021.3060666
# Error 500 when fetching references for 10.1007/s00371-022-02545-8
# Error 500 when fetching citations for 10.1111/cgf.142612
# Error 500 when fetching citations for 10.1109/MCG.2021.3090198
# Error 500 when fetching citations for 10.1016/j.cag.2020.09.016
# Error 500 when fetching citations for 10.1016/j.cag.2023.08.023
# Error 500 when fetching references for 10.1016/j.cag.2023.05.009
# Error 500 when fetching references for 10.1016/j.cag.2022.09.003
# Error 500 when fetching citations for 10.1111/cgf.14291
# Error 500 when fetching citations for 10.1007/s11042-023-17080-4
# Error 500 when fetching references for 10.1016/j.cag.2021.08.009
# Error 500 when fetching citations for 10.1007/s11042-023-16566-5
# Error 500 when fetching citations for 10.1109/TMM.2024.3374580
# Error 500 when fetching references for 10.1016/j.cag.2023.05.005
# Error 500 when fetching citations for 10.1007/s00371-021-02214-2Error 500 when fetching references for 10.1016/j.cag.2020.09.015
#
# Error 500 when fetching citations for 10.1007/s00371-024-03400-8
# Error 500 when fetching citations for 10.23919/DATE54114.2022.9774657
# Error 500 when fetching citations for 10.1109/TC.2021.3050978
# Error 500 when fetching references for 10.1109/TCSI.2023.3310876
# Error 500 when fetching citations for 10.1109/TC.2020.3006007
# Error 500 when fetching citations for 10.1145/3578503.3583613
# Error 500 when fetching references for 10.1145/3488585
# Error 500 when fetching citations for 10.1145/3578503.3583603
# Error 500 when fetching references for 10.1016/j.ipm.2024.103647
# Error 500 when fetching references for 10.1109/TNSM.2021.3125019
# Error 500 when fetching references for 10.1109/TNSM.2020.3044038
# Error 500 when fetching citations for 10.1016/j.comcom.2022.09.011
# Error 500 when fetching references for 10.1109/NOMS59830.2024.10575053
# Error 500 when fetching citations for 10.1109/INFOCOM48880.2022.9796848
# Error 500 when fetching references for 10.1109/TNSM.2023.3287651
# Error 500 when fetching citations for 10.1109/TNSM.2021.3123216
# Error 500 when fetching references for 10.1109/TWC.2023.3297014
# Error 500 when fetching citations for 10.1016/j.comnet.2020.107252
# Error 500 when fetching references for 10.1016/j.comnet.2021.108146
# Error 500 when fetching citations for 10.1016/j.comcom.2019.10.010
# Error 500 when fetching citations for 10.1016/j.jnca.2021.103213
# Error 500 when fetching references for 10.1109/TNSM.2023.3331755
# Error 500 when fetching references for 10.1109/JSAC.2020.3042420
# Error 500 when fetching citations for 10.1016/j.comnet.2021.108618
# Error 500 when fetching citations for 10.1109/TMC.2022.3154089
# Error 500 when fetching citations for 10.1109/NOMS56928.2023.10154448
# Error 500 when fetching references for 10.1007/s10878-021-00835-w
# Error 500 when fetching citations for 10.1007/s10878-023-01083-w
# Error 500 when fetching references for 10.1016/j.ejor.2021.05.041
# Error 500 when fetching references for 10.1287/trsc.2022.1176
# Error 500 when fetching citations for 10.1007/s10589-019-00154-1
# Error 500 when fetching citations for 10.1002/net.22213
# Error 500 when fetching citations for 10.1016/j.cor.2022.105842
# Error 500 when fetching citations for 10.1007/s11590-019-01530-wError 500 when fetching citations for 10.1007/s10589-020-00173-3
#
# Error 500 when fetching references for 10.1287/trsc.2022.1129
# Error 500 when fetching citations for 10.1287/trsc.2022.1129
# Error 500 when fetching citations for 10.1016/j.cor.2023.106527
# Error 500 when fetching references for 10.1016/j.ejor.2020.03.073
# Error 500 when fetching references for 10.1016/j.cor.2021.105637
# Error 500 when fetching citations for 10.1007/s10898-021-01001-6
# Error 500 when fetching citations for 10.1007/s11590-021-01719-y
# Error 500 when fetching references for 10.1080/01605682.2019.1582590
# Error 500 when fetching references for 10.1145/3421472Error 500 when fetching references for 10.1145/3594736
#
# Error 500 when fetching references for 10.1007/s10846-021-01321-5
# Error 500 when fetching citations for 10.1007/s10846-021-01345-x
# Error 500 when fetching references for 10.1007/s10846-020-01208-x
# Error 500 when fetching references for 10.1109/LRA.2022.3154482
# Error 500 when fetching citations for 10.1016/j.robot.2020.103607
# Error 500 when fetching citations for 10.1109/RE51729.2021.00015
# Error 500 when fetching citations for 10.1109/MS.2019.2955675
# Error 500 when fetching references for 10.1109/RE48521.2020.00022
# Error 500 when fetching citations for 10.1109/TSE.2022.3214764
# Error 500 when fetching citations for 10.1145/3510460
# Error 500 when fetching citations for 10.1016/j.jss.2021.111116
# Error 500 when fetching citations for 10.1109/MS.2019.2955937
# Error 500 when fetching references for 10.1109/MS.2021.3058652
# Error 500 when fetching references for 10.1016/j.infsof.2022.107142
# Error 500 when fetching references for 10.1016/j.jss.2020.110846Error 500 when fetching references for 10.1109/MS.2020.3033508
#
# Error 500 when fetching references for 10.1007/s10664-020-09832-9
# Error 500 when fetching citations for 10.1007/s00766-022-00377-5
# Error 500 when fetching references for 10.1016/j.jss.2022.111574
# Error 500 when fetching references for 10.1007/s10664-020-09936-2
# Error 500 when fetching citations for 10.1109/MS.2020.3042683
# Error 500 when fetching citations for 10.1007/s11219-020-09535-w
# Error 500 when fetching references for 10.1016/j.jss.2021.110904
# Error 500 when fetching references for 10.1007/s10664-022-10211-9
# Error 500 when fetching citations for 10.1109/ICSA47634.2020.00016Error 500 when fetching citations for 10.1002/spe.2946
#
# Error 500 when fetching references for 10.1007/s11219-024-09663-7
# Error 500 when fetching references for 10.1109/TSE.2020.3002496
# Error 500 when fetching citations for 10.1016/j.infsof.2021.106562
# Error 500 when fetching citations for 10.1007/s10664-022-10234-2
# Error 500 when fetching citations for 10.1016/j.jss.2021.111146
# Error 500 when fetching citations for 10.1016/j.infsof.2020.106505
# Error 500 when fetching citations for 10.1016/j.jss.2023.111708
# Error 500 when fetching citations for 10.1109/ESEM56168.2023.10304800
# Error 500 when fetching citations for 10.1109/MSR59073.2023.00087
# Error 500 when fetching references for 10.1109/TDSC.2021.3058057
# Error 500 when fetching references for 10.1109/TDSC.2018.2828306
# Error 500 when fetching references for 10.1016/j.cose.2022.102824
# Error 500 when fetching citations for 10.1109/TIFS.2023.3289448
# Error 500 when fetching citations for 10.1007/978-3-030-61792-9_50
# Error 500 when fetching citations for 10.1145/3618260.3649734
# Error 500 when fetching references for 10.1007/978-3-031-20624-5_4
# Error 500 when fetching references for 10.1016/j.disc.2022.112941
# Error 500 when fetching citations for 10.1016/j.tcs.2020.12.043
# Error 500 when fetching citations for 10.1016/j.disc.2024.114274
# Error 500 when fetching citations for 10.1016/j.dam.2022.12.021
# Error 500 when fetching references for 10.1016/j.patrec.2021.06.032
# Error 500 when fetching citations for 10.1016/j.jvcir.2020.102771
# Error 500 when fetching citations for 10.1016/j.patcog.2024.110499
# Error 500 when fetching references for 10.1109/WACV51458.2022.00076
# Error 500 when fetching citations for 10.1016/j.jvcir.2023.103775
# Error 500 when fetching references for 10.1016/j.cviu.2022.103409
# Error 500 when fetching references for 10.1016/j.jvcir.2024.104187
# Error 500 when fetching citations for 10.1016/j.patcog.2023.109359
# Processed 3289 publications in 307.89 seconds.
# Total citation edges after filtering: 1683
# Unique citation edges in the repository-only network: 1006
# Filtered citation edge list saved to 'citations_edge_list_repo_only.csv'.
